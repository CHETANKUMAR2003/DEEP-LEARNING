# %%
pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\chetan\anaconda3\lib\site-packages (2.4.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: filelock in c:\users\chetan\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\chetan\anaconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\users\chetan\anaconda3\lib\site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in c:\users\chetan\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\chetan\anaconda3\lib\site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\chetan\anaconda3\lib\site-packages (from torch) (2023.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\chetan\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\chetan\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)

# %%
import torch
from matplotlib import pyplot as plt
import cv2

# Load the YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Load an image
img = r"C:\Users\chetan\DEEP LEARNING\WEEK 6\obj.jpg"

# Inference
results = model(img)

# Results
results.print()  # Print detections
results.show()   # Display image with bounding boxes
# Out:
# requirements: Ultralytics requirements ['pillow>=10.3.0', 'requests>=2.32.2', 'tqdm>=4.66.3', 'setuptools>=70.0.0'] not found, attempting AutoUpdate...
# requirements:  AutoUpdate skipped (offline)
# Using cache found in C:\Users\chetan/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-10-17 Python-3.11.8 torch-2.4.1+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# C:\Users\chetan/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# image 1/1: 576x768 1 bicycle, 1 car, 1 dog
# Speed: 15.7ms pre-process, 110.4ms inference, 0.0ms NMS per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=768x576>
